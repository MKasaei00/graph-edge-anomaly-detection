# %%
# !rm -rf /content/graph-edge-anomaly-detection
# !git clone https://github.com/MKasaei00/graph-edge-anomaly-detection.git
# Out:
# Cloning into 'graph-edge-anomaly-detection'...
# remote: Enumerating objects: 329, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 329 (delta 1), reused 1 (delta 1), pack-reused 321 (from 3)
# Receiving objects: 100% (329/329), 135.91 MiB | 20.75 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
# Updating files: 100% (71/71), done.

# %%
# !sudo apt-get install unrar  # Install unrar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
# !pwd
# Out:
# /content

# %%
# !unzip /content/graph-edge-anomaly-detection/datasets/DDOS2019/metadata-files.zip -d /content/graph-edge-anomaly-detection/datasets/DDOS2019
# !unzip /content/graph-edge-anomaly-detection/datasets/DDOS2019/anoedge_g_DDOS2019_score.zip -d /content/graph-edge-anomaly-detection/datasets/DDOS2019
# Out:
# Archive:  /content/graph-edge-anomaly-detection/datasets/DDOS2019/metadata-files.zip
#   inflating: /content/graph-edge-anomaly-detection/datasets/DDOS2019/sum values.txt
#   inflating: /content/graph-edge-anomaly-detection/datasets/DDOS2019/max values.txt
#   inflating: /content/graph-edge-anomaly-detection/datasets/DDOS2019/min values.txt
#   inflating: /content/graph-edge-anomaly-detection/datasets/DDOS2019/q1 values.txt
#   inflating: /content/graph-edge-anomaly-detection/datasets/DDOS2019/q2 values.txt
#   inflating: /content/graph-edge-anomaly-detection/datasets/DDOS2019/q3 values.txt
# Archive:  /content/graph-edge-anomaly-detection/datasets/DDOS2019/anoedge_g_DDOS2019_score.zip
#   inflating: /content/graph-edge-anomaly-detection/datasets/DDOS2019/anoedge_g_DDOS2019_score.csv

# %%
import pandas as pd

# %%
directory = '/content/graph-edge-anomaly-detection/datasets/DDOS2019/'

max_values = pd.read_csv(directory + 'max values.txt', delimiter='\t', header=None)
min_values = pd.read_csv(directory + 'min values.txt', delimiter='\t', header=None)
q1_values = pd.read_csv(directory + 'q1 values.txt', delimiter='\t', header=None)
q2_values = pd.read_csv(directory + 'q2 values.txt', delimiter='\t', header=None)
q3_values = pd.read_csv(directory + 'q3 values.txt', delimiter='\t', header=None)
sum_values = pd.read_csv(directory + 'sum values.txt', delimiter='\t', header=None)
scores_dataframe = pd.read_csv(directory + 'anoedge_g_DDOS2019_score.csv', sep=' ', header=None);
scores_dataframe.columns = ['Score', 'Label']

# %%
max_values

# %%
min_values
# Out:
#           0
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...      ..
# 20364520  0
# 20364521  0
# 20364522  0
# 20364523  0
# 20364524  0
#
# [20364525 rows x 1 columns]

# %%
q1_values
# Out:
#           0
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...      ..
# 20364520  0
# 20364521  0
# 20364522  0
# 20364523  0
# 20364524  0
#
# [20364525 rows x 1 columns]

# %%
q2_values
# Out:
#           0
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...      ..
# 20364520  0
# 20364521  0
# 20364522  0
# 20364523  0
# 20364524  0
#
# [20364525 rows x 1 columns]

# %%
q3_values
# Out:
#           0
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...      ..
# 20364520  0
# 20364521  0
# 20364522  0
# 20364523  0
# 20364524  0
#
# [20364525 rows x 1 columns]

# %%
sum_values
# Out:
#                 0
# 0          1.0000
# 1          1.9000
# 2          2.9000
# 3          3.9000
# 4          4.9000
# ...           ...
# 20364520  14.6135
# 20364521  14.1522
# 20364522  13.7370
# 20364523  13.3633
# 20364524  13.0269
#
# [20364525 rows x 1 columns]

# %%
scores_dataframe
# Out:
#            Score  Label
# 0         1.0000      0
# 1         1.0000      0
# 2         1.3435      0
# 3         1.4142      0
# 4         2.1213      0
# ...          ...    ...
# 20364520  1.3935      1
# 20364521  5.8442      1
# 20364522  1.1977      0
# 20364523  1.8491      0
# 20364524  5.2604      1
#
# [20364525 rows x 2 columns]

# %%
# prompt: I have some data frames and I want to merge them in a way that columns are union of all
# and every row is the same as the row with same index in other dataframe

merged_df = pd.concat([scores_dataframe, min_values, q1_values, q2_values, q3_values, max_values, sum_values], axis=1)
merged_df.columns = ['score','label','min','q1','median','q3','max','sum']
merged_df
# Out:
#            score  label  min  q1  median  q3      max      sum
# 0         1.0000      0    0   0       0   0  1.00000   1.0000
# 1         1.0000      0    0   0       0   0  1.00000   1.9000
# 2         1.3435      0    0   0       0   0  1.00000   2.9000
# 3         1.4142      0    0   0       0   0  1.00000   3.9000
# 4         2.1213      0    0   0       0   0  2.00000   4.9000
# ...          ...    ...  ...  ..     ...  ..      ...      ...
# 20364520  1.3935      1    0   0       0   0  5.38240  14.6135
# 20364521  5.8442      1    0   0       0   0  5.84416  14.1522
# 20364522  1.1977      0    0   0       0   0  5.25974  13.7370
# 20364523  1.8491      0    0   0       0   0  4.73377  13.3633
# 20364524  5.2604      1    0   0       0   0  5.26039  13.0269
#
# [20364525 rows x 8 columns]

# %%
merged_df.to_csv('merged_data.csv', index=False)

# %%
# prompt: Save the file into zip with best compression

# !zip -9 merged_data.zip merged_data.csv -s 50m
# Out:
#   adding: merged_data.csv (deflated 82%)
